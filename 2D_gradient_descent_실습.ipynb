# %% [markdown]
# <a href="https://colab.research.google.com/github/vkdl/python/blob/main/2D_gradient_descent_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a + 3* b**4 +2* np.cos(a*b)

def grad_f(a,b): 
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] 
	theta = theta0     
	
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) 
	
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-1, -1], iters =30, alpha = 0.03)


fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')

a = np.arange(-3, 3, 0.25)
b = np.arange(-3, 3, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)

ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')



plt.show()
# Out:
# [ 3.08060461  1.07018381  0.82122237  0.68419549  0.5808401   0.48981312
#   0.40276744  0.31560019  0.22589959  0.13202751  0.03274893 -0.07292189
#  -0.18577678 -0.30641925 -0.43524441 -0.57240798 -0.71779605 -0.87100542
#  -1.03134265 -1.1978464  -1.36933343 -1.54446412 -1.72181956 -1.89998068
#  -2.07760009 -2.25345985 -2.42651082 -2.59589313 -2.76093958 -2.92116576
#  -3.07625131]
